# %%
Q1. Python function to calculate F-value for variance ratio test:

python
Copy code
import numpy as np
from scipy.stats import f

def variance_ratio_test(data1, data2):
    # Calculate the sample variances
    var1 = np.var(data1, ddof=1)
    var2 = np.var(data2, ddof=1)

    # Calculate the F-value and p-value for the variance ratio test
    f_value = var1 / var2
    p_value = 1 - f.cdf(f_value, len(data1) - 1, len(data2) - 1)

    return f_value, p_value
Q2. Python function to calculate critical F-value for a two-tailed test:

python
Copy code
from scipy.stats import f

def critical_f_value(alpha, dfn, dfd):
    return f.ppf(1 - alpha / 2, dfn, dfd)
Q3. Python program to generate random samples and perform F-test for variance equality:

python
Copy code
import numpy as np
from scipy.stats import f

def f_test_for_variances(sample1, sample2):
    # Calculate sample variances
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    # Calculate F-value and degrees of freedom
    dfn = len(sample1) - 1
    dfd = len(sample2) - 1
    f_value = var1 / var2

    # Calculate p-value for F-test
    p_value = 2 * (1 - f.cdf(f_value, dfn, dfd))

    return f_value, dfn, dfd, p_value

# Generate random samples from normal distributions
np.random.seed(42)
sample1 = np.random.normal(loc=0, scale=1, size=100)
sample2 = np.random.normal(loc=0, scale=1.5, size=100)

# Perform F-test for variance equality
f_value, dfn, dfd, p_value = f_test_for_variances(sample1, sample2)

print("F-value:", f_value)
print("Degrees of freedom (numerator):", dfn)
print("Degrees of freedom (denominator):", dfd)
print("p-value:", p_value)
Q4. Conducting F-test for known variances:

python
Copy code
from scipy.stats import f

# Given data
variance1 = 10
variance2 = 15
sample_size1 = 12
sample_size2 = 12
alpha = 0.05

# Degrees of freedom
dfn = sample_size1 - 1
dfd = sample_size2 - 1

# Calculate F-critical value
f_critical = f.ppf(1 - alpha / 2, dfn, dfd)

# Calculate F-value
f_value = variance1 / variance2

# Perform the F-test
if f_value > f_critical or f_value < 1 / f_critical:
    print("The variances are significantly different.")
else:
    print("The variances are not significantly different.")
Q5. Conducting F-test for variance claim:

python
Copy code
from scipy.stats import f

# Given data
claim_variance = 0.005
sample_variance = 0.006
sample_size = 25
alpha = 0.01

# Degrees of freedom
dfn = sample_size - 1
dfd = sample_size - 1

# Calculate F-critical value
f_critical = f.ppf(1 - alpha / 2, dfn, dfd)

# Calculate F-value
f_value = sample_variance / claim_variance

# Perform the F-test
if f_value > f_critical or f_value < 1 / f_critical:
    print("The claim is not justified. The variances are significantly different.")
else:
    print("The claim is justified. The variances are not significantly different.")
Q6. Python function to calculate mean and variance of F-distribution:

python
Copy code
from scipy.stats import f

def f_distribution_mean_variance(dfn, dfd):
    mean = dfd / (dfd - 2)
    variance = (2 * dfd**2 * (dfn + dfd - 2)) / (dfn * (dfd - 2)**2 * (dfd - 4))
    return mean, variance

# Example usage:
dfn = 5
dfd = 10
mean, variance = f_distribution_mean_variance(dfn, dfd)
print("Mean:", mean)
print("Variance:", variance)
Q7. Conducting F-test for unknown variances:

python
Copy code
from scipy.stats import f

# Given data
sample1_variance = 25
sample2_variance = 20
sample1_size = 10
sample2_size = 15
alpha = 0.10

# Degrees of freedom
dfn = sample1_size - 1
dfd = sample2_size - 1

# Calculate F-critical value
f_critical = f.ppf(1 - alpha / 2, dfn, dfd)

# Calculate F-value
f_value = sample1_variance / sample2_variance

# Perform the F-test
if f_value > f_critical or f_value < 1 / f_critical:
    print("The variances are significantly different.")
else:
    print("The variances are not significantly different.")
Q8. Conducting F-test for waiting times at restaurants:

python
Copy code
from scipy.stats import f

# Given data
restaurant_A = [24, 25, 28, 23, 22, 20, 27]
restaurant_B = [31, 33, 35, 30, 32, 36]
alpha = 0.05

# Degrees of freedom
dfn = len(restaurant_A) - 1
dfd = len(restaurant_B) - 1

# Calculate F-critical value
f_critical = f.ppf(1 - alpha / 2, dfn, dfd)

# Calculate sample variances
variance_A = np.var(restaurant_A, ddof=1)
variance_B = np.var(restaurant_B, ddof=1)

# Calculate F-value
f_value = variance_A / variance_B

# Perform the F-test
if f_value > f_critical or f_value < 1 / f_critical:
    print("The variances are significantly different.")
else:
    print("The variances are not significantly different.")
Q9. Conducting F-test for test scores of two groups:

python
Copy code
from scipy.stats import f

# Given data
group_A = [80, 85, 90, 92, 87, 83]
group_B = [75, 78, 82, 79, 81, 84]
alpha = 0.01

# Degrees of freedom
dfn = len(group_A) - 1
dfd = len(group_B) - 1

# Calculate F-critical value
f_critical = f.ppf(1 - alpha / 2, dfn, dfd)

# Calculate sample variances
variance_A = np.var(group_A, ddof=1)
variance_B = np.var(group_B, ddof=1)

# Calculate F-value
f_value = variance_A / variance_B

# Perform the F-test
if f_value > f_critical or f_value < 1 / f_critical:
    print("The variances are significantly different.")
else:
    print("The variances are not significantly different."
